# %%
import random
import numpy as np
import os
import cv2
import glob
from PIL import Image
import PIL.ImageOps    

#다음 변수를 수정하여 새로 만들 이미지 갯수를 정합니다.
num_augmented_images = 10001

file_path = 'without_helmet/without_helmet'
file_names = os.listdir(file_path)
total_origin_image_num = len(file_names)
augment_cnt = 1

for i in range(1, num_augmented_images):
    change_picture_index = random.randrange(1, total_origin_image_num-1)
    print(change_picture_index)
    print(file_names[change_picture_index])
    file_name = file_names[change_picture_index]
    
    origin_image_path = 'without_helmet/without_helmet/' + file_name
    print(origin_image_path)
    image = Image.open(origin_image_path)
    random_augment = random.randrange(1,4)
    
    if(random_augment == 1):
        #이미지 좌우 반전
        print("invert")
        inverted_image = image.transpose(Image.FLIP_LEFT_RIGHT)
        inverted_image.save('without_helmet_gen/without' + 'inverted_' + str(augment_cnt) + '.png')
        
    elif(random_augment == 2):
        #이미지 기울이기
        print("rotate")
        rotated_image = image.rotate(random.randrange(-20, 20))
        rotated_image.save('without_helmet_gen/without' + 'rotated_' + str(augment_cnt) + '.png')
        
    elif(random_augment == 3):
        #노이즈 추가하기
        img = cv2.imread(origin_image_path)
        print("noise")
        row,col,ch= img.shape
        mean = 0
        var = 0.1
        sigma = var**0.5
        gauss = np.random.normal(mean,sigma,(row,col,ch))
        gauss = gauss.reshape(row,col,ch)
        noisy_array = img + gauss
        noisy_image = Image.fromarray(np.uint8(noisy_array)).convert('RGB')
        noisy_image.save('without_helmet_gen/without' + 'noiseAdded_' + str(augment_cnt) + '.png')
        
    augment_cnt += 1
# Out:
# 733
# without_helmet_759.png
# without_helmet/without_helmet/without_helmet_759.png
# invert
# 878
# without_helmet_89.png
# without_helmet/without_helmet/without_helmet_89.png
# rotate
# 368
# without_helmet_43.png
# without_helmet/without_helmet/without_helmet_43.png
# invert
# 724
# without_helmet_750.png
# without_helmet/without_helmet/without_helmet_750.png
# noise
# 449
# without_helmet_502.png
# without_helmet/without_helmet/without_helmet_502.png
# rotate
# 451
# without_helmet_504.png
# without_helmet/without_helmet/without_helmet_504.png
# invert
# 644
# without_helmet_679.png
# without_helmet/without_helmet/without_helmet_679.png
# noise
# 827
# without_helmet_843.png
# without_helmet/without_helmet/without_helmet_843.png
# rotate
# 808
# without_helmet_826.png
# without_helmet/without_helmet/without_helmet_826.png
# noise
# 21
# without_helmet_117.png
# without_helmet/without_helmet/without_helmet_117.png
# noise
# 15
# without_helmet_111.png
# ...

# %%
import random
import numpy as np
import os
import cv2
import glob
from PIL import Image
import PIL.ImageOps    

#다음 변수를 수정하여 새로 만들 이미지 갯수를 정합니다.
num_augmented_images = 10001

file_path = 'with_helmet/with_helmet'
file_names = os.listdir(file_path)
total_origin_image_num = len(file_names)
augment_cnt = 1

for i in range(1, num_augmented_images):
    change_picture_index = random.randrange(1, total_origin_image_num-1)
    print(change_picture_index)
    print(file_names[change_picture_index])
    file_name = file_names[change_picture_index]
    
    origin_image_path = 'with_helmet/with_helmet/' + file_name
    print(origin_image_path)
    image = Image.open(origin_image_path)
    random_augment = random.randrange(1,4)
    
    if(random_augment == 1):
        #이미지 좌우 반전
        print("invert")
        inverted_image = image.transpose(Image.FLIP_LEFT_RIGHT)
        inverted_image.save('with_helmet_gen/with' + 'inverted_' + str(augment_cnt) + '.png')
        
    elif(random_augment == 2):
        #이미지 기울이기
        print("rotate")
        rotated_image = image.rotate(random.randrange(-20, 20))
        rotated_image.save('with_helmet_gen/with' + 'rotated_' + str(augment_cnt) + '.png')
        
    elif(random_augment == 3):
        #노이즈 추가하기
        img = cv2.imread(origin_image_path)
        print("noise")
        row,col,ch= img.shape
        mean = 0
        var = 0.1
        sigma = var**0.5
        gauss = np.random.normal(mean,sigma,(row,col,ch))
        gauss = gauss.reshape(row,col,ch)
        noisy_array = img + gauss
        noisy_image = Image.fromarray(np.uint8(noisy_array)).convert('RGB')
        noisy_image.save('with_helmet_gen/with' + 'noiseAdded_' + str(augment_cnt) + '.png')
        
    augment_cnt += 1
# Out:
# 394
# with_helmet_336.png
# with_helmet/with_helmet/with_helmet_336.png
# noise
# 210
# with_helmet_170.png
# with_helmet/with_helmet/with_helmet_170.png
# rotate
# 26
# with_helmet_1020.png
# with_helmet/with_helmet/with_helmet_1020.png
# rotate
# 302
# with_helmet_253.png
# with_helmet/with_helmet/with_helmet_253.png
# rotate
# 816
# with_helmet_716.png
# with_helmet/with_helmet/with_helmet_716.png
# invert
# 7
# with_helmet_1003.png
# with_helmet/with_helmet/with_helmet_1003.png
# invert
# 794
# with_helmet_697.png
# with_helmet/with_helmet/with_helmet_697.png
# rotate
# 1008
# with_helmet_89.png
# with_helmet/with_helmet/with_helmet_89.png
# noise
# 973
# with_helmet_858.png
# with_helmet/with_helmet/with_helmet_858.png
# rotate
# 75
# with_helmet_1065.png
# with_helmet/with_helmet/with_helmet_1065.png
# rotate
# 475
# with_helmet_409.png
# with_helmet/with_helmet/with_helmet_409.png
# noise
# 129
# with_helmet_1113.png
# with_helmet/with_helmet/with_helmet_1113.png
# noise
# ...
